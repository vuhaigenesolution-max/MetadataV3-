# %% [markdown]
# Lấy các giá trị cột A-B-C-T-I từ dòng số 22 của mỗi file của sheet Sample loai bo các giá trị có hàng trống và tạo df

# %%
pattern = re.compile(r"metadata_(.+?)_(\d{8}).*\.xlsx?$", re.IGNORECASE)
